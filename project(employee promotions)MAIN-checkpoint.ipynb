# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s
import warnings as w
w.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
import pandasql as psl

# %%
Employee=pd.read_csv(r"C:\Users\Dlc\Downloads\archive.zip",header=0)
Employee_bk=Employee.copy()
Employee.sample(10)
# Out:
#        employee_id         department     region         education gender  \
# 44101         1326         Technology   region_7        Bachelor's      f
# 45354        44189  Sales & Marketing  region_11               NaN      m
# 27107        38953         Operations  region_15        Bachelor's      m
# 22688        64757        Procurement   region_2  Master's & above      f
# 5144         15736        Procurement   region_5        Bachelor's      m
# 21033        51659        Procurement   region_2  Master's & above      m
# 53298         6250  Sales & Marketing  region_22  Master's & above      m
# 1170         55333                R&D  region_22  Master's & above      m
# 43347        64223        Procurement  region_14  Master's & above      f
# 21116        29296  Sales & Marketing   region_4        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 44101            sourcing                1   33                   3.0
# 45354               other                1   35                   3.0
# 27107               other                1   43                   4.0
# 22688               other                1   48                   1.0
# 5144             sourcing                1   29                   3.0
# 21033            sourcing                1   44                   1.0
# 53298               other                1   41                   2.0
# 1170                other                2   28                   NaN
# 43347               other                1   33                   3.0
# 21116            sourcing                1   28                   NaN
#
#        length_of_service  awards_won  avg_training_score  is_promoted
# 44101                  4           0                80.0            0
# 45354                  7           0                54.0            0
# 27107                 14           0                64.0            0
# 22688                 15           0                70.0            0
# 5144                   5           0                70.0            0
# 21033                  6           0                67.0            0
# 53298                  4           0                46.0            0
# 1170                   1           0                87.0            0
# 43347                  6           0                72.0            0
# 21116                  1           0                46.0            0

# %%
Employee_d=Employee[Employee.duplicated(keep='last')]
Employee_d
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, awards_won, avg_training_score, is_promoted]
# Index: []

# %%
Employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  awards_won            54808 non-null  int64
#  11  avg_training_score    52248 non-null  float64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 5.4+ MB

# %%
Employee.nunique()
# Out:
# employee_id             54808
# department                  9
# region                     34
# education                   3
# gender                      2
# recruitment_channel         3
# no_of_trainings            10
# age                        41
# previous_year_rating        5
# length_of_service          35
# awards_won                  2
# avg_training_score         59
# is_promoted                 2
# dtype: int64

# %%
Employee.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service    awards_won  avg_training_score   is_promoted
# count       54808.000000  54808.000000        52248.000000  54808.000000
# mean            5.865512      0.023172           63.712238      0.085170
# std             4.265094      0.150450           13.521910      0.279137
# min             1.000000      0.000000           39.000000      0.000000
# 25%             3.000000      0.000000           51.000000      0.000000
# 50%             5.000000      0.000000           60.000000      0.000000
# 75%             7.000000      0.000000           77.000000      0.000000
# max            37.000000      1.000000           99.000000      1.000000

# %%
del Employee['employee_id']

# %%
del Employee['region']

# %%
del Employee['gender']

# %%
Employee.department.value_counts()
# Out:
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: department, dtype: int64

# %%
Employee.education.value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
Employee.recruitment_channel.value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
Employee['department']=Employee['department'].map({'Sales & Marketing':0,'Operations':1,'Technology':2,'Procurement':3,'Analytics':4,'Finance':5,'HR':6,'Legal':7,'R&D':8})
Employee['education']=Employee['education'].map({"Bachelor's":0,"Master's & above":1,'Below Secondary':2})
Employee['recruitment_channel']=Employee['recruitment_channel'].map({'other':0,'sourcing':1,'referred':2})

# %%
emp=Employee.fillna(0)

# %%
emp.sample(10)
# Out:
#        department  education  recruitment_channel  no_of_trainings  age  \
# 18363           1        1.0                    0                1   44
# 43113           5        0.0                    1                1   31
# 54581           5        0.0                    0                1   29
# 15973           2        1.0                    1                1   54
# 41112           1        0.0                    0                1   32
# 18191           2        1.0                    1                1   34
# 53557           1        0.0                    0                1   49
# 29762           1        0.0                    1                1   45
# 21092           0        1.0                    0                1   35
# 28064           4        0.0                    0                1   35
#
#        previous_year_rating  length_of_service  awards_won  \
# 18363                   3.0                 16           0
# 43113                   4.0                  4           0
# 54581                   3.0                  6           0
# 15973                   1.0                 24           0
# 41112                   4.0                  6           0
# 18191                   1.0                  9           0
# 53557                   2.0                 12           0
# 29762                   3.0                  4           1
# 21092                   3.0                  7           0
# 28064                   3.0                  7           0
#
#        avg_training_score  is_promoted
# 18363                62.0            0
# 43113                 0.0            0
# 54581                64.0            0
# 15973                80.0            0
# 41112                 0.0            0
# 18191                79.0            0
# 53557                63.0            0
# 29762                63.0            0
# 21092                51.0            1
# 28064                85.0            0

# %%
emp.columns
# Out:
# Index(['department', 'education', 'recruitment_channel', 'no_of_trainings',
#        'age', 'previous_year_rating', 'length_of_service', 'awards_won',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            54808 non-null  int64
#  1   education             54808 non-null  float64
#  2   recruitment_channel   54808 non-null  int64
#  3   no_of_trainings       54808 non-null  int64
#  4   age                   54808 non-null  int64
#  5   previous_year_rating  54808 non-null  float64
#  6   length_of_service     54808 non-null  int64
#  7   awards_won            54808 non-null  int64
#  8   avg_training_score    54808 non-null  float64
#  9   is_promoted           54808 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 4.2 MB

# %%
cols=['department','no_of_trainings','age','previous_year_rating','length_of_service','avg_training_score']

# %%
IndepVar = []
for col in emp.columns:
    if col != 'is_promoted':
        IndepVar.append(col)
TargetVar = 'is_promoted'

x = emp[IndepVar]
y = emp[TargetVar]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((38365, 9), (16443, 9), (38365,), (16443,))

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler=MinMaxScaler(feature_range=(0, 1))

x_train[cols]=mmscaler.fit_transform(x_train[cols])
x_train=pd.DataFrame(x_train)

x_test[cols]=mmscaler.fit_transform(x_test[cols])
x_test=pd.DataFrame(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred_prob=model.predict_proba(x_test)

# %%
#to display the algoritm parameters
param=model.get_params()
print(param)
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
KNN_Results=pd.read_csv(r"C:\Users\Dlc\Downloads\KNN_Results.csv",header=0)
KNN_Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):

    k = a

    # Build the model

    ModelKNN = KNeighborsClassifier(n_neighbors=k)

    # Train the model

    ModelKNN.fit(x_train, y_train)

    # Predict the model

    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)

    print('KNN_K_value = ', a)

    # Print the model name

    print('Model Name: ', ModelKNN)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNN_Results = KNN_Results.append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[  396   937]
#  [  858 14252]]
# Outcome values :
#  396 937 858 14252
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.32      0.30      0.31      1333
#            0       0.94      0.94      0.94     15110
#
#     accuracy                           0.89     16443
#    macro avg       0.63      0.62      0.62     16443
# weighted avg       0.89      0.89      0.89     16443
#
# Accuracy : 89.1 %
# Precision : 31.6 %
# Recall : 29.7 %
# F1 Score : 0.306
# Specificity or True Negative Rate : 94.3 %
# Balanced Accuracy : 62.0 %
# MCC : 0.247
# roc_auc_score: 0.62
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[  217  1116]
#  [   89 15021]]
# Outcome values :
#  217 1116 89 15021
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.16      0.26      1333
#            0       0.93      0.99      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.82      0.58      0.61     16443
# weighted avg       0.91      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 70.9 %
# Recall : 16.3 %
# F1 Score : 0.265
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 57.8 %
# MCC : 0.317
# roc_auc_score: 0.578
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[  289  1044]
#  [  248 14862]]
# Outcome values :
#  289 1044 248 14862
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.54      0.22      0.31      1333
#            0       0.93      0.98      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.74      0.60      0.63     16443
# weighted avg       0.90      0.92      0.91     16443
#
# Accuracy : 92.1 %
# Precision : 53.8 %
# Recall : 21.7 %
# F1 Score : 0.309
# Specificity or True Negative Rate : 98.4 %
# Balanced Accuracy : 60.0 %
# MCC : 0.308
# roc_auc_score: 0.6
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[  209  1124]
#  [   51 15059]]
# Outcome values :
#  209 1124 51 15059
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.80      0.16      0.26      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.58      0.61     16443
# weighted avg       0.92      0.93      0.91     16443
#
# Accuracy : 92.9 %
# Precision : 80.4 %
# Recall : 15.7 %
# F1 Score : 0.262
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 57.7 %
# MCC : 0.336
# roc_auc_score: 0.577
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  253  1080]
#  [  102 15008]]
# Outcome values :
#  253 1080 102 15008
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.19      0.30      1333
#            0       0.93      0.99      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.82      0.59      0.63     16443
# weighted avg       0.92      0.93      0.91     16443
#
# Accuracy : 92.8 %
# Precision : 71.3 %
# Recall : 19.0 %
# F1 Score : 0.3
# Specificity or True Negative Rate : 99.3 %
# Balanced Accuracy : 59.2 %
# MCC : 0.344
# roc_auc_score: 0.592
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[  203  1130]
#  [   37 15073]]
# Outcome values :
#  203 1130 37 15073
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.15      0.26      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.89      0.57      0.61     16443
# weighted avg       0.92      0.93      0.91     16443
#
# Accuracy : 92.9 %
# Precision : 84.6 %
# Recall : 15.2 %
# F1 Score : 0.258
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 57.5 %
# MCC : 0.341
# roc_auc_score: 0.575
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[  233  1100]
#  [   77 15033]]
# Outcome values :
#  233 1100 77 15033
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.75      0.17      0.28      1333
#            0       0.93      0.99      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.84      0.58      0.62     16443
# weighted avg       0.92      0.93      0.91     16443
#
# Accuracy : 92.8 %
# Precision : 75.2 %
# Recall : 17.5 %
# F1 Score : 0.284
# Specificity or True Negative Rate : 99.5 %
# Balanced Accuracy : 58.5 %
# MCC : 0.341
# roc_auc_score: 0.585
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[  184  1149]
#  [   41 15069]]
# Outcome values :
#  184 1149 41 15069
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.82      0.14      0.24      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.57      0.60     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.8 %
# Precision : 81.8 %
# Recall : 13.8 %
# F1 Score : 0.236
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.8 %
# MCC : 0.318
# roc_auc_score: 0.568
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[  204  1129]
#  [   61 15049]]
# Outcome values :
#  204 1129 61 15049
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.77      0.15      0.26      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.85      0.57      0.61     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.8 %
# Precision : 77.0 %
# Recall : 15.3 %
# F1 Score : 0.255
# Specificity or True Negative Rate : 99.6 %
# Balanced Accuracy : 57.4 %
# MCC : 0.323
# roc_auc_score: 0.575
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[  169  1164]
#  [   39 15071]]
# Outcome values :
#  169 1164 39 15071
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.81      0.13      0.22      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 81.2 %
# Recall : 12.7 %
# F1 Score : 0.219
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.2 %
# MCC : 0.303
# roc_auc_score: 0.562
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[  188  1145]
#  [   58 15052]]
# Outcome values :
#  188 1145 58 15052
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.76      0.14      0.24      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.85      0.57      0.60     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 76.4 %
# Recall : 14.1 %
# F1 Score : 0.238
# Specificity or True Negative Rate : 99.6 %
# Balanced Accuracy : 56.8 %
# MCC : 0.308
# roc_auc_score: 0.569
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[  162  1171]
#  [   37 15073]]
# Outcome values :
#  162 1171 37 15073
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.81      0.12      0.21      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 81.4 %
# Recall : 12.2 %
# F1 Score : 0.211
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 56.0 %
# MCC : 0.297
# roc_auc_score: 0.56
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[  178  1155]
#  [   50 15060]]
# Outcome values :
#  178 1155 50 15060
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.78      0.13      0.23      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.85      0.57      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 78.1 %
# Recall : 13.4 %
# F1 Score : 0.228
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.6 %
# MCC : 0.304
# roc_auc_score: 0.565
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[  161  1172]
#  [   38 15072]]
# Outcome values :
#  161 1172 38 15072
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.81      0.12      0.21      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 80.9 %
# Recall : 12.1 %
# F1 Score : 0.21
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 55.9 %
# MCC : 0.295
# roc_auc_score: 0.559
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[  174  1159]
#  [   51 15059]]
# Outcome values :
#  174 1159 51 15059
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.77      0.13      0.22      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.85      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 77.3 %
# Recall : 13.1 %
# F1 Score : 0.223
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.4 %
# MCC : 0.299
# roc_auc_score: 0.564
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[  160  1173]
#  [   33 15077]]
# Outcome values :
#  160 1173 33 15077
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.83      0.12      0.21      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.88      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.7 %
# Precision : 82.9 %
# Recall : 12.0 %
# F1 Score : 0.21
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 55.9 %
# MCC : 0.299
# roc_auc_score: 0.559
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[  166  1167]
#  [   46 15064]]
# Outcome values :
#  166 1167 46 15064
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.78      0.12      0.21      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.86      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 78.3 %
# Recall : 12.5 %
# F1 Score : 0.215
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.1 %
# MCC : 0.294
# roc_auc_score: 0.561
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[  155  1178]
#  [   37 15073]]
# Outcome values :
#  155 1178 37 15073
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.81      0.12      0.20      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.87      0.56      0.58     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 80.7 %
# Recall : 11.6 %
# F1 Score : 0.203
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 55.7 %
# MCC : 0.289
# roc_auc_score: 0.557
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[  162  1171]
#  [   48 15062]]
# Outcome values :
#  162 1171 48 15062
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.77      0.12      0.21      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.85      0.56      0.59     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 77.1 %
# Recall : 12.2 %
# F1 Score : 0.21
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 56.0 %
# MCC : 0.288
# roc_auc_score: 0.559
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[  152  1181]
#  [   38 15072]]
# Outcome values :
#  152 1181 38 15072
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.80      0.11      0.20      1333
#            0       0.93      1.00      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.86      0.56      0.58     16443
# weighted avg       0.92      0.93      0.90     16443
#
# Accuracy : 92.6 %
# Precision : 80.0 %
# Recall : 11.4 %
# F1 Score : 0.2
# Specificity or True Negative Rate : 99.7 %
# Balanced Accuracy : 55.6 %
# MCC : 0.285
# roc_auc_score: 0.556

# %%
KNN_Results.head(20)
# Out:
#                               Model Name KNN K Value True_Positive  \
# 0    KNeighborsClassifier(n_neighbors=1)           1           396
# 1    KNeighborsClassifier(n_neighbors=2)           2           217
# 2    KNeighborsClassifier(n_neighbors=3)           3           289
# 3    KNeighborsClassifier(n_neighbors=4)           4           209
# 4                 KNeighborsClassifier()           5           253
# 5    KNeighborsClassifier(n_neighbors=6)           6           203
# 6    KNeighborsClassifier(n_neighbors=7)           7           233
# 7    KNeighborsClassifier(n_neighbors=8)           8           184
# 8    KNeighborsClassifier(n_neighbors=9)           9           204
# 9   KNeighborsClassifier(n_neighbors=10)          10           169
# 10  KNeighborsClassifier(n_neighbors=11)          11           188
# 11  KNeighborsClassifier(n_neighbors=12)          12           162
# 12  KNeighborsClassifier(n_neighbors=13)          13           178
# 13  KNeighborsClassifier(n_neighbors=14)          14           161
# 14  KNeighborsClassifier(n_neighbors=15)          15           174
# 15  KNeighborsClassifier(n_neighbors=16)          16           160
# 16  KNeighborsClassifier(n_neighbors=17)          17           166
# 17  KNeighborsClassifier(n_neighbors=18)          18           155
# 18  KNeighborsClassifier(n_neighbors=19)          19           162
# 19  KNeighborsClassifier(n_neighbors=20)          20           152
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0             937            858         14252     0.891      0.316   0.297
# 1            1116             89         15021     0.927      0.709   0.163
# 2            1044            248         14862     0.921      0.538   0.217
# 3            1124             51         15059     0.929      0.804   0.157
# 4            1080            102         15008     0.928      0.713   0.190
# 5            1130             37         15073     0.929      0.846   0.152
# 6            1100             77         15033     0.928      0.752   0.175
# 7            1149             41         15069     0.928      0.818   0.138
# 8            1129             61         15049     0.928      0.770   0.153
# 9            1164             39         15071     0.927      0.812   0.127
# 10           1145             58         15052     0.927      0.764   0.141
# 11           1171             37         15073     0.927      0.814   0.122
# 12           1155             50         15060     0.927      0.781   0.134
# 13           1172             38         15072     0.926      0.809   0.121
# 14           1159             51         15059     0.926      0.773   0.131
# 15           1173             33         15077     0.927      0.829   0.120
# 16           1167             46         15064     0.926      0.783   0.125
# 17           1178             37         15073     0.926      0.807   0.116
# 18           1171             48         15062     0.926      0.771   0.122
# 19           1181             38         15072     0.926      0.800   0.114
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0      0.306        0.943  0.247       0.620145              0.620
# 1      0.265        0.994  0.317       0.578450              0.578
# 2      0.309        0.984  0.308       0.600196              0.600
# 3      0.262        0.997  0.336       0.576707              0.577
# 4      0.300        0.993  0.344       0.591523              0.592
# 5      0.258        0.998  0.341       0.574920              0.575
# 6      0.284        0.995  0.341       0.584849              0.585
# 7      0.236        0.997  0.318       0.567661              0.568
# 8      0.255        0.996  0.323       0.574501              0.574
# 9      0.219        0.997  0.303       0.562100              0.562
# 10     0.238        0.996  0.308       0.568598              0.568
# 11     0.211        0.998  0.297       0.559541              0.560
# 12     0.228        0.997  0.304       0.565112              0.566
# 13     0.210        0.997  0.295       0.559133              0.559
# 14     0.223        0.997  0.299       0.563579              0.564
# 15     0.210        0.998  0.299       0.558923              0.559
# 16     0.215        0.997  0.294       0.560743              0.561
# 17     0.203        0.998  0.289       0.556915              0.557
# 18     0.210        0.997  0.288       0.559177              0.560
# 19     0.200        0.997  0.285       0.555757              0.556

# %%
y_predKNN=ModelKNN.predict(x_test)

# %%
Results=pd.DataFrame({'diagnosis_A':y_test,'diagnosis_p':y_predKNN})

ResultsFinal=Employee_bk.merge(Results,left_index=True,right_index=True)

ResultsFinal.sample(5)
# Out:
#        employee_id         department     region         education gender  \
# 32129        18188  Sales & Marketing   region_2  Master's & above      f
# 6923         22645  Sales & Marketing  region_27  Master's & above      m
# 460          25351  Sales & Marketing  region_14  Master's & above      m
# 32968         6874  Sales & Marketing   region_7        Bachelor's      m
# 48221        41596  Sales & Marketing   region_2  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 32129               other                1   45                   1.0
# 6923                other                2   40                   3.0
# 460              sourcing                1   45                   3.0
# 32968               other                2   46                   1.0
# 48221               other                1   58                   3.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted  \
# 32129                 12           0                53.0            0
# 6923                   4           0                47.0            0
# 460                   17           0                49.0            0
# 32968                 13           0                48.0            0
# 48221                  7           0                49.0            0
#
#        diagnosis_A  diagnosis_p
# 32129            0            0
# 6923             0            0
# 460              0            0
# 32968            0            0
# 48221            0            0

# %%
EMResults=pd.read_csv(r"C:\Users\Dlc\Downloads\EMResults .csv",header=0)
EMResults.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-456abab4baa6> in <cell line: 1>()
# ----> 1 EMResults=pd.read_csv(r"C:\Users\Dlc\Downloads\EMResults .csv",header=0)
#       2 EMResults.head()
#
# NameError: name 'pd' is not defined

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.naive_bayes import GaussianNB
#from sklearn.svm import SVC

# Create objects of classification algorithms with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
#ModelKNN = KNeighborsClassifier(n_neighbors=5)
#ModelGNB = GaussianNB()
#ModelSVM = SVC(probability=True)

# Evalution matrix for all the algorithms

#MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelGNB, ModelSVM]
MM = [ModelLR, ModelDC, ModelRF, ModelET]
for models in MM:

    # Train the model training dataset

    models.fit(x_train, y_train)

    # Prediction the model with test dataset

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    Model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    #
    plt.plot(fpr, tpr, label= 'Classification Model' % Model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('---------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive': tp,
               'False_Negative': fn,
               'False_Positive': fp,
               'True_Negative': tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
#======================================================================================================================>
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[   99  1234]
#  [   34 15076]]
# Outcome values :
#  99 1234 34 15076
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.74      0.07      0.14      1333
#            0       0.92      1.00      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.83      0.54      0.55     16443
# weighted avg       0.91      0.92      0.89     16443
#
# Accuracy : 92.3 %
# Precision : 74.4 %
# Recall : 7.4 %
# F1 Score : 0.135
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 53.6 %
# MCC : 0.219
# roc_auc_score: 0.536
# ---------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[  542   791]
#  [  965 14145]]
# Outcome values :
#  542 791 965 14145
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.36      0.41      0.38      1333
#            0       0.95      0.94      0.94     15110
#
#     accuracy                           0.89     16443
#    macro avg       0.65      0.67      0.66     16443
# weighted avg       0.90      0.89      0.90     16443
#
# Accuracy : 89.3 %
# Precision : 36.0 %
# Recall : 40.7 %
# F1 Score : 0.382
# Specificity or True Negative Rate : 93.6 %
# Balanced Accuracy : 67.2 %
# MCC : 0.324
# roc_auc_score: 0.671
# ---------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[  430   903]
#  [  251 14859]]
# Outcome values :
#  430 903 251 14859
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.63      0.32      0.43      1333
#            0       0.94      0.98      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.79      0.65      0.69     16443
# weighted avg       0.92      0.93      0.92     16443
#
# Accuracy : 93.0 %
# Precision : 63.1 %
# Recall : 32.3 %
# F1 Score : 0.427
# Specificity or True Negative Rate : 98.3 %
# Balanced Accuracy : 65.3 %
# MCC : 0.419
# roc_auc_score: 0.653
# ---------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[  417   916]
#  [  328 14782]]
# Outcome values :
#  417 916 328 14782
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.56      0.31      0.40      1333
#            0       0.94      0.98      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.75      0.65      0.68     16443
# weighted avg       0.91      0.92      0.91     16443
#
# Accuracy : 92.4 %
# Precision : 56.0 %
# Recall : 31.3 %
# F1 Score : 0.401
# Specificity or True Negative Rate : 97.8 %
# Balanced Accuracy : 64.6 %
# MCC : 0.382
# roc_auc_score: 0.646
# ---------------------------------------------------------------------------

# %%
Results=pd.DataFrame({'is_promoted_A':y_test,'is_promoted_P':y_pred})
ResultsFinal=Employee_bk.merge(Results,left_index=True,right_index=True)

ResultsFinal.sample(10)
# Out:
#        employee_id         department     region   education gender  \
# 41314        22247  Sales & Marketing  region_22  Bachelor's      f
# 44852        63766          Analytics  region_22         NaN      m
# 8037         54442          Analytics  region_20  Bachelor's      m
# 20790        47595         Operations  region_32  Bachelor's      m
# 47731        25011  Sales & Marketing  region_30  Bachelor's      m
# 7294         51724                 HR  region_22  Bachelor's      m
# 13069         4174  Sales & Marketing  region_11  Bachelor's      m
# 1808         21694  Sales & Marketing   region_6  Bachelor's      m
# 41704        54084         Technology   region_8  Bachelor's      f
# 13179        11415         Operations  region_27  Bachelor's      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 41314            sourcing                1   25                   1.0
# 44852               other                1   27                   NaN
# 8037             sourcing                1   32                   4.0
# 20790            sourcing                1   39                   5.0
# 47731            sourcing                1   32                   NaN
# 7294                other                2   27                   3.0
# 13069               other                1   37                   1.0
# 1808             sourcing                1   25                   3.0
# 41704               other                1   27                   NaN
# 13179               other                1   32                   3.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted  \
# 41314                  2           0                50.0            0
# 44852                  1           0                83.0            0
# 8037                   3           0                83.0            0
# 20790                  7           0                57.0            1
# 47731                  1           0                47.0            0
# 7294                   2           0                50.0            0
# 13069                  7           0                51.0            0
# 1808                   2           0                50.0            0
# 41704                  1           0                77.0            0
# 13179                  3           0                55.0            0
#
#        is_promoted_A  is_promoted_P
# 41314              0              0
# 44852              0              0
# 8037               0              0
# 20790              1              0
# 47731              0              0
# 7294               0              0
# 13069              0              0
# 1808               0              0
# 41704              0              0
# 13179              0              0

# %%
EMResults=pd.read_csv(r"C:\Users\Dlc\Downloads\EMResults .csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Create objects of classification algorithm with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=5)
ModelSVM = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)
ModelGNB = GaussianNB()

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET,ModelKNN,ModelSVM,ModelGNB]
for models in MM:

    # Fit the model

    models.fit(x_train, y_train)

    # Prediction

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[   99  1234]
#  [   34 15076]]
# Outcome values :
#  99 1234 34 15076
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.74      0.07      0.14      1333
#            0       0.92      1.00      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.83      0.54      0.55     16443
# weighted avg       0.91      0.92      0.89     16443
#
# Accuracy : 92.3 %
# Precision : 74.4 %
# Recall : 7.4 %
# F1 Score : 0.135
# Specificity or True Negative Rate : 99.8 %
# Balanced Accuracy : 53.6 %
# MCC : 0.219
# roc_auc_score: 0.536
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[  539   794]
#  [  945 14165]]
# Outcome values :
#  539 794 945 14165
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.36      0.40      0.38      1333
#            0       0.95      0.94      0.94     15110
#
#     accuracy                           0.89     16443
#    macro avg       0.66      0.67      0.66     16443
# weighted avg       0.90      0.89      0.90     16443
#
# Accuracy : 89.4 %
# Precision : 36.3 %
# Recall : 40.4 %
# F1 Score : 0.383
# Specificity or True Negative Rate : 93.7 %
# Balanced Accuracy : 67.1 %
# MCC : 0.326
# roc_auc_score: 0.671
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[  424   909]
#  [  231 14879]]
# Outcome values :
#  424 909 231 14879
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.32      0.43      1333
#            0       0.94      0.98      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.79      0.65      0.69     16443
# weighted avg       0.92      0.93      0.92     16443
#
# Accuracy : 93.1 %
# Precision : 64.7 %
# Recall : 31.8 %
# F1 Score : 0.427
# Specificity or True Negative Rate : 98.5 %
# Balanced Accuracy : 65.2 %
# MCC : 0.423
# roc_auc_score: 0.651
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[  406   927]
#  [  316 14794]]
# Outcome values :
#  406 927 316 14794
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.56      0.30      0.40      1333
#            0       0.94      0.98      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.75      0.64      0.68     16443
# weighted avg       0.91      0.92      0.91     16443
#
# Accuracy : 92.4 %
# Precision : 56.2 %
# Recall : 30.5 %
# F1 Score : 0.395
# Specificity or True Negative Rate : 97.9 %
# Balanced Accuracy : 64.2 %
# MCC : 0.378
# roc_auc_score: 0.642
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  253  1080]
#  [  102 15008]]
# Outcome values :
#  253 1080 102 15008
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.19      0.30      1333
#            0       0.93      0.99      0.96     15110
#
#     accuracy                           0.93     16443
#    macro avg       0.82      0.59      0.63     16443
# weighted avg       0.92      0.93      0.91     16443
#
# Accuracy : 92.8 %
# Precision : 71.3 %
# Recall : 19.0 %
# F1 Score : 0.3
# Specificity or True Negative Rate : 99.3 %
# Balanced Accuracy : 59.2 %
# MCC : 0.344
# roc_auc_score: 0.592
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(class_weight='balanced', probability=True, random_state=42)
# Confusion matrix :
#  [[  806   527]
#  [ 3543 11567]]
# Outcome values :
#  806 527 3543 11567
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.19      0.60      0.28      1333
#            0       0.96      0.77      0.85     15110
#
#     accuracy                           0.75     16443
#    macro avg       0.57      0.69      0.57     16443
# weighted avg       0.89      0.75      0.80     16443
#
# Accuracy : 75.2 %
# Precision : 18.5 %
# Recall : 60.5 %
# F1 Score : 0.284
# Specificity or True Negative Rate : 76.6 %
# Balanced Accuracy : 68.6 %
# MCC : 0.229
# roc_auc_score: 0.685
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[  155  1178]
#  [  216 14894]]
# Outcome values :
#  155 1178 216 14894
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.42      0.12      0.18      1333
#            0       0.93      0.99      0.96     15110
#
#     accuracy                           0.92     16443
#    macro avg       0.67      0.55      0.57     16443
# weighted avg       0.89      0.92      0.89     16443
#
# Accuracy : 91.5 %
# Precision : 41.8 %
# Recall : 11.6 %
# F1 Score : 0.182
# Specificity or True Negative Rate : 98.6 %
# Balanced Accuracy : 55.1 %
# MCC : 0.187
# roc_auc_score: 0.551
# -----------------------------------------------------------------------------------------------------

# %%
EMResults.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()            99
# 1                           DecisionTreeClassifier()           539
# 2  (DecisionTreeClassifier(max_features='auto', r...           424
# 3  (ExtraTreeClassifier(random_state=1151881201),...           406
# 4                             KNeighborsClassifier()           253
# 5  SVC(class_weight='balanced', probability=True,...           806
# 6                                       GaussianNB()           155
# 7                               LogisticRegression()            99
# 8                           DecisionTreeClassifier()           539
# 9  (DecisionTreeClassifier(max_features='auto', r...           429
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0           1234             34         15076     0.923      0.744   0.074
# 1            794            945         14165     0.894      0.363   0.404
# 2            909            231         14879     0.931      0.647   0.318
# 3            927            316         14794     0.924      0.562   0.305
# 4           1080            102         15008     0.928      0.713   0.190
# 5            527           3543         11567     0.752      0.185   0.605
# 6           1178            216         14894     0.915      0.418   0.116
# 7           1234             34         15076     0.923      0.744   0.074
# 8            794            978         14132     0.892      0.355   0.404
# 9            904            253         14857     0.930      0.629   0.322
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.135        0.998  0.219       0.536009              0.536
# 1     0.383        0.937  0.326       0.670905              0.671
# 2     0.427        0.985  0.423       0.651396              0.652
# 3     0.395        0.979  0.378       0.641831              0.642
# 4     0.300        0.993  0.344       0.591523              0.592
# 5     0.284        0.766  0.229       0.685085              0.686
# 6     0.182        0.986  0.187       0.550992              0.551
# 7     0.135        0.998  0.219       0.536009              0.536
# 8     0.378        0.935  0.320       0.669813              0.670
# 9     0.426        0.983  0.418       0.652543              0.652
